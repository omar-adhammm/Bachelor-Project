# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": ["# CF Pipeline — Google Colab\n"]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Cell 1 — Check GPU\n",
    "!nvidia-smi\n",
    "import torch\n",
    "print(f'GPU: {torch.cuda.get_device_name(0)}')\n",
    "print(f'VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')"
   ],
   "outputs": [],
   "execution_count": null
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Cell 2 — Clone repo and install dependencies\n",
    "!git clone https://github.com/YOUR_USERNAME/YOUR_REPO_NAME.git\n",
    "%cd YOUR_REPO_NAME\n",
    "!pip install groq jsonlines tqdm python-dotenv pyyaml transformers accelerate -q"
   ],
   "outputs": [],
   "execution_count": null
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Cell 3 — Mount Google Drive to save results\n",
    "from google.colab import drive\n",
    "drive.mount('/content/drive')\n",
    "import os\n",
    "os.makedirs('/content/drive/MyDrive/thesis_cf_pairs', exist_ok=True)\n",
    "print('Drive mounted!')"
   ],
   "outputs": [],
   "execution_count": null
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Cell 4 — Copy any existing progress from Drive (resume support)\n",
    "import shutil, os\n",
    "os.makedirs('outputs/cf_pairs', exist_ok=True)\n",
    "for split in ['train', 'validation', 'test']:\n",
    "    src = f'/content/drive/MyDrive/thesis_cf_pairs/{split}_cf_pairs.jsonl'\n",
    "    dst = f'outputs/cf_pairs/{split}_cf_pairs.jsonl'\n",
    "    if os.path.exists(src):\n",
    "        shutil.copy(src, dst)\n",
    "        print(f'Restored {split} from Drive')\n",
    "    else:\n",
    "        print(f'No existing {split} file — starting fresh')"
   ],
   "outputs": [],
   "execution_count": null
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Cell 5 — HuggingFace login (needed for Llama gated model)\n",
    "from huggingface_hub import login\n",
    "login(token='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')"
   ],
   "outputs": [],
   "execution_count": null
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Cell 6 — Run train split\n",
    "!python counterfactuals/pipeline.py --split train"
   ],
   "outputs": [],
   "execution_count": null
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Cell 7 — Save train results to Drive immediately\n",
    "shutil.copy(\n",
    "    'outputs/cf_pairs/train_cf_pairs.jsonl',\n",
    "    '/content/drive/MyDrive/thesis_cf_pairs/train_cf_pairs.jsonl'\n",
    ")\n",
    "print('Train results saved to Drive!')"
   ],
   "outputs": [],
   "execution_count": null
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Cell 8 — Run validation split\n",
    "!python counterfactuals/pipeline.py --split validation"
   ],
   "outputs": [],
   "execution_count": null
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Cell 9 — Run test split\n",
    "!python counterfactuals/pipeline.py --split test"
   ],
   "outputs": [],
   "execution_count": null
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Cell 10 — Save all results to Drive\n",
    "for split in ['train', 'validation', 'test']:\n",
    "    src = f'outputs/cf_pairs/{split}_cf_pairs.jsonl'\n",
    "    dst = f'/content/drive/MyDrive/thesis_cf_pairs/{split}_cf_pairs.jsonl'\n",
    "    if os.path.exists(src):\n",
    "        shutil.copy(src, dst)\n",
    "        print(f'Saved {split} to Drive')"
   ],
   "outputs": [],
   "execution_count": null
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.10.0"
  },
  "accelerator": "GPU"
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
